# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Set Tensorflow to 1.15

# %%
# %tensorflow_version 1.x

# %% [markdown]
# if a directory doesn't exist for the classifier run this

# %%
# %cd /content/drive/My\ Drive
# !mkdir TensorflowClassifier
# Out:
# /content/drive/My Drive
# mkdir: cannot create directory ‘TensorflowClassifier’: File exists

# %% [markdown]
# change directory to the classifier directory

# %%
# %cd /content/drive/My\ Drive/TensorflowClassifier
# Out:
# /content/drive/My Drive/TensorflowClassifier

# %%
import dataset
import tensorflow as tf
import time
import numpy as np
import os

start = time.time()
try:

    # Total iterations
    final_iter = 30000
    
    # Assign the batch value
    batch_size = 16

    #20% of the data will automatically be used for validation
    validation_size = 0.2
    img_size = 256
    num_channels = 3
    train_path='data/train'

    #Prepare input data
    if not os.path.exists(train_path):
        print("No such directory")
        raise Exception
    classes = os.listdir(train_path)
    num_classes = len(classes)    

    # We shall load all the training and validation images and labels into memory using openCV and use that during training
    data = dataset.read_train_sets(train_path, img_size, classes, validation_size=validation_size)

    # Display the stats
    print("Complete reading input data. Will Now print a snippet of it")
    print("Number of files in Training-set:\t\t{}".format(len(data.train.labels)))
    print("Number of files in Validation-set:\t{}".format(len(data.valid.labels)))
    session = tf.Session()
    x = tf.placeholder(tf.float32, shape=[None, img_size,img_size,num_channels], name='x')

    ## labels
    y_true = tf.placeholder(tf.float32, shape=[None, num_classes], name='y_true')
    y_true_cls = tf.argmax(y_true, dimension=1)


    ##Network graph params
    filter_size_conv1 = 3 
    num_filters_conv1 = 32

    filter_size_conv2 = 3
    num_filters_conv2 = 32

    filter_size_conv3 = 3
    num_filters_conv3 = 64
        
    fc_layer_size = 128

    def create_weights(shape):
        return tf.Variable(tf.truncated_normal(shape, stddev=0.05))

    def create_biases(size):
        return tf.Variable(tf.constant(0.05, shape=[size]))

    # Function to create a convolutional layer
    def create_convolutional_layer(input,
                   num_input_channels, 
                   conv_filter_size,        
                   num_filters):  
        
        ## We shall define the weights that will be trained using create_weights function.
        weights = create_weights(shape=[conv_filter_size, conv_filter_size, num_input_channels, num_filters])
        ## We create biases using the create_biases function. These are also trained.
        biases = create_biases(num_filters)

        ## Creating the convolutional layer
        layer = tf.nn.conv2d(input=input,
                         filter=weights,
                         strides=[1, 1, 1, 1],
                         padding='SAME')

        layer += biases

        ## We shall be using max-pooling.  
        layer = tf.nn.max_pool(value=layer,
                                ksize=[1, 2, 2, 1],
                                strides=[1, 2, 2, 1],
                                padding='SAME')
        ## Output of pooling is fed to Relu which is the activation function for us.
        layer = tf.nn.relu(layer)

        return layer

        
    # Function to create a Flatten Layer
    def create_flatten_layer(layer):
        #We know that the shape of the layer will be [batch_size img_size img_size num_channels] 
        # But let's get it from the previous layer.
        layer_shape = layer.get_shape()

        ## Number of features will be img_height * img_width* num_channels. But we shall calculate it in place of hard-coding it.
        num_features = layer_shape[1:4].num_elements()

        ## Now, we Flatten the layer so we shall have to reshape to num_features
        layer = tf.reshape(layer, [-1, num_features])

        return layer

    # Function to create a Fully - Connected Layer
    def create_fc_layer(input,          
                 num_inputs,    
                 num_outputs,
                 use_relu=True):
        
        #Let's define trainable weights and biases.
        weights = create_weights(shape=[num_inputs, num_outputs])
        biases = create_biases(num_outputs)

        # Fully connected layer takes input x and produces wx+b.Since, these are matrices, we use matmul function in Tensorflow
        layer = tf.matmul(input, weights) + biases
        if use_relu:
            layer = tf.nn.relu(layer)

        return layer

    # Create all the layers
    layer_conv1 = create_convolutional_layer(input=x,
                   num_input_channels=num_channels,
                   conv_filter_size=filter_size_conv1,
                   num_filters=num_filters_conv1)
    layer_conv2 = create_convolutional_layer(input=layer_conv1,
                   num_input_channels=num_filters_conv1,
                   conv_filter_size=filter_size_conv2,
                   num_filters=num_filters_conv2)

    layer_conv3= create_convolutional_layer(input=layer_conv2,
                   num_input_channels=num_filters_conv2,
                   conv_filter_size=filter_size_conv3,
                   num_filters=num_filters_conv3)
              
    layer_flat = create_flatten_layer(layer_conv3)

    layer_fc1 = create_fc_layer(input=layer_flat,
                         num_inputs=layer_flat.get_shape()[1:4].num_elements(),
                         num_outputs=fc_layer_size,
                         use_relu=True)

    layer_fc2 = create_fc_layer(input=layer_fc1,
                         num_inputs=fc_layer_size,
                         num_outputs=num_classes,
                         use_relu=False) 

    y_pred = tf.nn.softmax(layer_fc2,name='y_pred')
    #probability model

    y_pred_cls = tf.argmax(y_pred, dimension=1)
    session.run(tf.global_variables_initializer())
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(logits=layer_fc2,
                                                        labels=y_true)
    cost = tf.reduce_mean(cross_entropy)
    optimizer = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(cost)
    correct_prediction = tf.equal(y_pred_cls, y_true_cls)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))


    session.run(tf.global_variables_initializer()) 

    # Display all stats for every epoch
    def show_progress(epoch, feed_dict_train, feed_dict_validate, val_loss,total_epochs):
        acc = session.run(accuracy, feed_dict=feed_dict_train)
        val_acc = session.run(accuracy, feed_dict=feed_dict_validate)
        msg = "Training Epoch {0}/{4} --- Training Accuracy: {1:>6.1%}, Validation Accuracy: {2:>6.1%},  Validation Loss: {3:.3f}"
        print(msg.format(epoch + 1, acc, val_acc, val_loss,total_epochs))

    total_iterations = 0

    saver = tf.train.Saver()
    
    print("")

    # Training Function
    def train(num_iteration):
        global total_iterations
        
        for i in range(total_iterations,
                       total_iterations + num_iteration):

            x_batch, y_true_batch, _, cls_batch = data.train.next_batch(batch_size)
            x_valid_batch, y_valid_batch, _, valid_cls_batch = data.valid.next_batch(batch_size)

            
            feed_dict_tr = {x: x_batch,
                               y_true: y_true_batch}
            feed_dict_val = {x: x_valid_batch,
                                  y_true: y_valid_batch}

            session.run(optimizer, feed_dict=feed_dict_tr)

            if i % int(data.train.num_examples/batch_size) == 0: 
                val_loss = session.run(cost, feed_dict=feed_dict_val)
                epoch = int(i / int(data.train.num_examples/batch_size))
                #print(data.train.num_examples)
                #print(batch_size)
                #print(int(data.train.num_examples/batch_size))
                #print(i)

                total_epochs = int(num_iteration/int(data.train.num_examples/batch_size)) + 1
                show_progress(epoch, feed_dict_tr, feed_dict_val, val_loss,total_epochs)
                saver.save(session, 'models/siteClassifier')

        total_iterations += num_iteration

    train(num_iteration = final_iter)

except Exception as e:
    print("Exception:",e)

# Calculate execution time
end = time.time()
dur = end-start
print("")
if dur<60:
    print("Execution Time:",dur,"seconds")
elif dur>60 and dur<3600:
    dur=dur/60
    print("Execution Time:",dur,"minutes")
else:
    dur=dur/(60*60)
    print("Execution Time:",dur,"hours")
# Out:
# Going to read training images
# Now going to read site2pwrplnt files (Index: 0)
# Now going to read site2ds files (Index: 1)
# Now going to read site2solar files (Index: 2)
# Complete reading input data. Will Now print a snippet of it
# Number of files in Training-set:		154
# Number of files in Validation-set:	38
# WARNING:tensorflow:From <ipython-input-4-9648f65eff30>:41: calling argmax (from tensorflow.python.ops.math_ops) with dimension is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
#
# Training Epoch 1/3334 --- Training Accuracy:  43.8%, Validation Accuracy:  18.8%,  Validation Loss: 1.551
# Training Epoch 2/3334 --- Training Accuracy:  31.2%, Validation Accuracy:  25.0%,  Validation Loss: 1.126
# Training Epoch 3/3334 --- Training Accuracy:  31.2%, Validation Accuracy:  43.8%,  Validation Loss: 1.061
# Training Epoch 4/3334 --- Training Accuracy:  43.8%, Validation Accuracy:  18.8%,  Validation Loss: 1.151
# Training Epoch 5/3334 --- Training Accuracy:  31.2%, Validation Accuracy:  43.8%,  Validation Loss: 1.073
# Training Epoch 6/3334 --- Training Accuracy:  68.8%, Validation Accuracy:  43.8%,  Validation Loss: 1.126
# Training Epoch 7/3334 --- Training Accuracy:  31.2%, Validation Accuracy:  43.8%,  Validation Loss: 1.076
# Training Epoch 8/3334 --- Training Accuracy:  56.2%, Validation Accuracy:  31.2%,  Validation Loss: 1.112
# Training Epoch 9/3334 --- Training Accuracy:  56.2%, Validation Accuracy:  43.8%,  Validation Loss: 1.070
# Training Epoch 10/3334 --- Training Accuracy:  56.2%, Validation Accuracy:  31.2%,  Validation Loss: 1.098
# Training Epoch 11/3334 --- Training Accuracy:  56.2%, Validation Accuracy:  50.0%,  Validation Loss: 1.055
# Training Epoch 12/3334 --- Training Accuracy:  56.2%, Validation Accuracy:  37.5%,  Validation Loss: 1.078
# Training Epoch 13/3334 --- Training Accuracy:  56.2%, Validation Accuracy:  50.0%,  Validation Loss: 1.031
# Training Epoch 14/3334 --- Training Accuracy:  56.2%, Validation Accuracy:  31.2%,  Validation Loss: 1.059
# Training Epoch 15/3334 --- Training Accuracy:  62.5%, Validation Accuracy:  56.2%,  Validation Loss: 1.006
# Training Epoch 16/3334 --- Training Accuracy:  62.5%, Validation Accuracy:  43.8%,  Validation Loss: 1.036
# Training Epoch 17/3334 --- Training Accuracy:  68.8%, Validation Accuracy:  68.8%,  Validation Loss: 0.974
# Training Epoch 18/3334 --- Training Accuracy:  75.0%, Validation Accuracy:  43.8%,  Validation Loss: 0.999
# Training Epoch 19/3334 --- Training Accuracy:  75.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.933
# Training Epoch 20/3334 --- Training Accuracy:  75.0%, Validation Accuracy:  43.8%,  Validation Loss: 0.963
# Training Epoch 21/3334 --- Training Accuracy:  81.2%, Validation Accuracy:  68.8%,  Validation Loss: 0.891
# Training Epoch 22/3334 --- Training Accuracy:  81.2%, Validation Accuracy:  50.0%,  Validation Loss: 0.915
# Training Epoch 23/3334 --- Training Accuracy:  81.2%, Validation Accuracy:  68.8%,  Validation Loss: 0.844
# Training Epoch 24/3334 --- Training Accuracy:  93.8%, Validation Accuracy:  50.0%,  Validation Loss: 0.856
# Training Epoch 25/3334 --- Training Accuracy:  93.8%, Validation Accuracy:  68.8%,  Validation Loss: 0.792
# Training Epoch 26/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.799
# Training Epoch 27/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 0.736
# Training Epoch 28/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.750
# Training Epoch 29/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 0.677
# Training Epoch 30/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 0.684
# Training Epoch 31/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 0.624
# Training Epoch 32/3334 --- Training Accuracy:  93.8%, Validation Accuracy:  62.5%,  Validation Loss: 0.663
# Training Epoch 33/3334 --- Training Accuracy:  93.8%, Validation Accuracy:  56.2%,  Validation Loss: 0.602
# Training Epoch 34/3334 --- Training Accuracy:  87.5%, Validation Accuracy:  75.0%,  Validation Loss: 0.620
# Training Epoch 35/3334 --- Training Accuracy:  93.8%, Validation Accuracy:  68.8%,  Validation Loss: 0.568
# Training Epoch 36/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.575
# Training Epoch 37/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.503
# Training Epoch 38/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.544
# Training Epoch 39/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 0.467
# Training Epoch 40/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.525
# Training Epoch 41/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 0.436
# Training Epoch 42/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.497
# Training Epoch 43/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 0.415
# Training Epoch 44/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.475
# Training Epoch 45/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.384
# Training Epoch 46/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.465
# Training Epoch 47/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  93.8%,  Validation Loss: 0.354
# Training Epoch 48/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.470
# Training Epoch 49/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  93.8%,  Validation Loss: 0.317
# Training Epoch 50/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.493
# Training Epoch 51/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  93.8%,  Validation Loss: 0.296
# Training Epoch 52/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.476
# Training Epoch 53/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  93.8%,  Validation Loss: 0.272
# Training Epoch 54/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.467
# Training Epoch 55/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  93.8%,  Validation Loss: 0.249
# Training Epoch 56/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.482
# Training Epoch 57/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.237
# Training Epoch 58/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.476
# Training Epoch 59/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.224
# Training Epoch 60/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.481
# Training Epoch 61/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.213
# Training Epoch 62/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.485
# Training Epoch 63/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.204
# Training Epoch 64/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.489
# Training Epoch 65/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.195
# Training Epoch 66/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.492
# Training Epoch 67/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.188
# Training Epoch 68/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.501
# Training Epoch 69/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.181
# Training Epoch 70/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.504
# Training Epoch 71/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.176
# Training Epoch 72/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.510
# Training Epoch 73/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.171
# Training Epoch 74/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.515
# Training Epoch 75/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.167
# Training Epoch 76/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.522
# Training Epoch 77/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.163
# Training Epoch 78/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.530
# Training Epoch 79/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.161
# Training Epoch 80/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.527
# Training Epoch 81/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.158
# Training Epoch 82/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.540
# Training Epoch 83/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.156
# Training Epoch 84/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.548
# Training Epoch 85/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.153
# Training Epoch 86/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.558
# Training Epoch 87/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.152
# Training Epoch 88/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.560
# Training Epoch 89/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.151
# Training Epoch 90/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.569
# Training Epoch 91/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.149
# Training Epoch 92/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.578
# Training Epoch 93/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.149
# Training Epoch 94/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.581
# Training Epoch 95/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.147
# Training Epoch 96/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.587
# Training Epoch 97/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.146
# Training Epoch 98/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.593
# Training Epoch 99/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.146
# Training Epoch 100/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.605
# Training Epoch 101/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.146
# Training Epoch 102/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.608
# Training Epoch 103/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.145
# Training Epoch 104/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.615
# Training Epoch 105/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.146
# Training Epoch 106/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.618
# Training Epoch 107/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.144
# Training Epoch 108/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.625
# Training Epoch 109/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.145
# Training Epoch 110/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.632
# Training Epoch 111/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.146
# Training Epoch 112/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.637
# Training Epoch 113/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.144
# Training Epoch 114/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.645
# Training Epoch 115/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.145
# Training Epoch 116/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.651
# Training Epoch 117/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.144
# Training Epoch 118/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.658
# Training Epoch 119/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  93.8%,  Validation Loss: 0.146
# Training Epoch 120/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.662
# Training Epoch 121/3334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%,  Validation Loss: 0.144
# Training Epoch 122/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.669
# Training Epoch 123/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  93.8%,  Validation Loss: 0.145
# Training Epoch 124/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.676
# Training Epoch 125/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  93.8%,  Validation Loss: 0.147
# Training Epoch 126/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.680
# Training Epoch 127/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  93.8%,  Validation Loss: 0.145
# Training Epoch 128/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.687
# Training Epoch 129/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  93.8%,  Validation Loss: 0.146
# Training Epoch 130/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.692
# Training Epoch 131/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  93.8%,  Validation Loss: 0.147
# Training Epoch 132/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.703
# Training Epoch 133/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  93.8%,  Validation Loss: 0.147
# Training Epoch 134/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.702
# Training Epoch 135/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  93.8%,  Validation Loss: 0.147
# Training Epoch 136/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.713
# Training Epoch 137/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  93.8%,  Validation Loss: 0.148
# Training Epoch 138/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.713
# Training Epoch 139/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.148
# Training Epoch 140/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.719
# Training Epoch 141/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.149
# Training Epoch 142/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.725
# Training Epoch 143/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.149
# Training Epoch 144/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.733
# Training Epoch 145/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.150
# Training Epoch 146/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.733
# Training Epoch 147/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.150
# Training Epoch 148/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.738
# Training Epoch 149/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.151
# Training Epoch 150/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.747
# Training Epoch 151/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.152
# Training Epoch 152/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.747
# Training Epoch 153/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.152
# Training Epoch 154/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.755
# Training Epoch 155/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.152
# Training Epoch 156/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.763
# Training Epoch 157/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.153
# Training Epoch 158/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.761
# Training Epoch 159/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.153
# Training Epoch 160/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.768
# Training Epoch 161/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.155
# Training Epoch 162/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.773
# Training Epoch 163/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.154
# Training Epoch 164/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.779
# Training Epoch 165/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.155
# Training Epoch 166/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.784
# Training Epoch 167/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.155
# Training Epoch 168/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.790
# Training Epoch 169/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.157
# Training Epoch 170/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.788
# Training Epoch 171/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.156
# Training Epoch 172/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.796
# Training Epoch 173/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.157
# Training Epoch 174/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.800
# Training Epoch 175/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.159
# Training Epoch 176/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.805
# Training Epoch 177/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.158
# Training Epoch 178/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.815
# Training Epoch 179/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.161
# Training Epoch 180/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.808
# Training Epoch 181/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.159
# Training Epoch 182/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.818
# Training Epoch 183/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.161
# Training Epoch 184/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.822
# Training Epoch 185/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.161
# Training Epoch 186/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.826
# Training Epoch 187/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.162
# Training Epoch 188/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.830
# Training Epoch 189/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.163
# Training Epoch 190/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.833
# Training Epoch 191/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.163
# Training Epoch 192/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.838
# Training Epoch 193/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.165
# Training Epoch 194/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.841
# Training Epoch 195/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.164
# Training Epoch 196/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.846
# Training Epoch 197/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.165
# Training Epoch 198/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.850
# Training Epoch 199/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.166
# Training Epoch 200/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.853
# Training Epoch 201/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.167
# Training Epoch 202/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.857
# Training Epoch 203/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.167
# Training Epoch 204/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.862
# Training Epoch 205/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.168
# Training Epoch 206/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.869
# Training Epoch 207/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.170
# Training Epoch 208/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.864
# Training Epoch 209/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.169
# Training Epoch 210/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.875
# Training Epoch 211/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.169
# Training Epoch 212/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.879
# Training Epoch 213/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.171
# Training Epoch 214/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.878
# Training Epoch 215/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.171
# Training Epoch 216/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.887
# Training Epoch 217/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.173
# Training Epoch 218/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.884
# Training Epoch 219/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.173
# Training Epoch 220/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.893
# Training Epoch 221/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.173
# Training Epoch 222/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.895
# Training Epoch 223/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.174
# Training Epoch 224/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.897
# Training Epoch 225/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.175
# Training Epoch 226/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.903
# Training Epoch 227/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.175
# Training Epoch 228/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.906
# Training Epoch 229/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.176
# Training Epoch 230/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.910
# Training Epoch 231/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.176
# Training Epoch 232/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.912
# Training Epoch 233/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.178
# Training Epoch 234/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.917
# Training Epoch 235/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.178
# Training Epoch 236/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.920
# Training Epoch 237/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.179
# Training Epoch 238/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.924
# Training Epoch 239/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.179
# Training Epoch 240/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.927
# Training Epoch 241/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.181
# Training Epoch 242/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.931
# Training Epoch 243/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.181
# Training Epoch 244/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.934
# Training Epoch 245/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.181
# Training Epoch 246/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.940
# Training Epoch 247/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.183
# Training Epoch 248/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.939
# Training Epoch 249/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.183
# Training Epoch 250/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.946
# Training Epoch 251/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.184
# Training Epoch 252/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.947
# Training Epoch 253/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.186
# Training Epoch 254/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.948
# Training Epoch 255/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.186
# Training Epoch 256/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.956
# Training Epoch 257/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.185
# Training Epoch 258/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.958
# Training Epoch 259/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.188
# Training Epoch 260/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.957
# Training Epoch 261/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.186
# Training Epoch 262/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.965
# Training Epoch 263/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.188
# Training Epoch 264/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.968
# Training Epoch 265/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.189
# Training Epoch 266/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.967
# Training Epoch 267/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.189
# Training Epoch 268/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.973
# Training Epoch 269/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.190
# Training Epoch 270/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.977
# Training Epoch 271/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.190
# Training Epoch 272/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.982
# Training Epoch 273/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.192
# Training Epoch 274/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.980
# Training Epoch 275/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.193
# Training Epoch 276/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.987
# Training Epoch 277/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.192
# Training Epoch 278/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.988
# Training Epoch 279/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.194
# Training Epoch 280/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 0.995
# Training Epoch 281/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.194
# Training Epoch 282/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.995
# Training Epoch 283/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.197
# Training Epoch 284/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 0.995
# Training Epoch 285/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.195
# Training Epoch 286/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 1.003
# Training Epoch 287/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.196
# Training Epoch 288/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.004
# Training Epoch 289/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.198
# Training Epoch 290/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.005
# Training Epoch 291/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.198
# Training Epoch 292/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.009
# Training Epoch 293/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.198
# Training Epoch 294/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.015
# Training Epoch 295/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.199
# Training Epoch 296/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.016
# Training Epoch 297/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.200
# Training Epoch 298/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.017
# Training Epoch 299/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.201
# Training Epoch 300/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%,  Validation Loss: 1.026
# Training Epoch 301/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.201
# Training Epoch 302/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.025
# Training Epoch 303/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.202
# Training Epoch 304/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.026
# Training Epoch 305/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.203
# Training Epoch 306/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.034
# Training Epoch 307/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.203
# Training Epoch 308/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.033
# Training Epoch 309/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.204
# Training Epoch 310/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.035
# Training Epoch 311/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.205
# Training Epoch 312/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.040
# Training Epoch 313/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.205
# Training Epoch 314/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.043
# Training Epoch 315/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.206
# Training Epoch 316/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.048
# Training Epoch 317/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.207
# Training Epoch 318/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.049
# Training Epoch 319/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.208
# Training Epoch 320/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.049
# Training Epoch 321/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.208
# Training Epoch 322/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.056
# Training Epoch 323/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.208
# Training Epoch 324/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.059
# Training Epoch 325/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.211
# Training Epoch 326/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.057
# Training Epoch 327/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.210
# Training Epoch 328/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.065
# Training Epoch 329/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.210
# Training Epoch 330/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.065
# Training Epoch 331/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.212
# Training Epoch 332/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.067
# Training Epoch 333/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.212
# Training Epoch 334/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.072
# Training Epoch 335/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.213
# Training Epoch 336/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.076
# Training Epoch 337/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.213
# Training Epoch 338/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.077
# Training Epoch 339/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.215
# Training Epoch 340/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.078
# Training Epoch 341/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.215
# Training Epoch 342/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.083
# Training Epoch 343/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.216
# Training Epoch 344/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.086
# Training Epoch 345/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.216
# Training Epoch 346/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.087
# Training Epoch 347/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.217
# Training Epoch 348/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.089
# Training Epoch 349/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.217
# Training Epoch 350/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.095
# Training Epoch 351/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.219
# Training Epoch 352/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.096
# Training Epoch 353/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.220
# Training Epoch 354/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.096
# Training Epoch 355/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.220
# Training Epoch 356/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.104
# Training Epoch 357/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.220
# Training Epoch 358/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.105
# Training Epoch 359/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.222
# Training Epoch 360/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.105
# Training Epoch 361/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.222
# Training Epoch 362/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.111
# Training Epoch 363/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.222
# Training Epoch 364/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.112
# Training Epoch 365/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.223
# Training Epoch 366/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.113
# Training Epoch 367/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.224
# Training Epoch 368/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.117
# Training Epoch 369/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.225
# Training Epoch 370/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.122
# Training Epoch 371/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.225
# Training Epoch 372/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.122
# Training Epoch 373/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.226
# Training Epoch 374/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.124
# Training Epoch 375/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.226
# Training Epoch 376/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.130
# Training Epoch 377/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.227
# Training Epoch 378/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.130
# Training Epoch 379/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.228
# Training Epoch 380/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.132
# Training Epoch 381/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.229
# Training Epoch 382/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.136
# Training Epoch 383/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.229
# Training Epoch 384/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.140
# Training Epoch 385/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.229
# Training Epoch 386/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.142
# Training Epoch 387/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.232
# Training Epoch 388/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.141
# Training Epoch 389/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.231
# Training Epoch 390/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.149
# Training Epoch 391/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.232
# Training Epoch 392/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.148
# Training Epoch 393/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.233
# Training Epoch 394/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.149
# Training Epoch 395/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.233
# Training Epoch 396/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.153
# Training Epoch 397/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.233
# Training Epoch 398/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.158
# Training Epoch 399/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.235
# Training Epoch 400/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.158
# Training Epoch 401/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.235
# Training Epoch 402/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.160
# Training Epoch 403/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.236
# Training Epoch 404/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.165
# Training Epoch 405/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.236
# Training Epoch 406/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.167
# Training Epoch 407/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.238
# Training Epoch 408/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.167
# Training Epoch 409/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.238
# Training Epoch 410/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.173
# Training Epoch 411/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.238
# Training Epoch 412/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.174
# Training Epoch 413/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.239
# Training Epoch 414/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.177
# Training Epoch 415/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.240
# Training Epoch 416/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.179
# Training Epoch 417/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.241
# Training Epoch 418/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.185
# Training Epoch 419/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.241
# Training Epoch 420/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.184
# Training Epoch 421/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.242
# Training Epoch 422/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.185
# Training Epoch 423/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.242
# Training Epoch 424/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.188
# Training Epoch 425/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.244
# Training Epoch 426/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.192
# Training Epoch 427/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.244
# Training Epoch 428/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.195
# Training Epoch 429/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.244
# Training Epoch 430/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.198
# Training Epoch 431/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.245
# Training Epoch 432/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.198
# Training Epoch 433/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.247
# Training Epoch 434/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.200
# Training Epoch 435/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.246
# Training Epoch 436/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.206
# Training Epoch 437/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.247
# Training Epoch 438/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.206
# Training Epoch 439/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  87.5%,  Validation Loss: 0.248
# Training Epoch 440/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%,  Validation Loss: 1.208
# ...
# Training Epoch 3189/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.910
# Training Epoch 3190/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.630
# Training Epoch 3191/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.910
# Training Epoch 3192/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.629
# Training Epoch 3193/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.911
# Training Epoch 3194/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.629
# Training Epoch 3195/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.911
# Training Epoch 3196/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.629
# Training Epoch 3197/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.911
# Training Epoch 3198/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.629
# Training Epoch 3199/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.912
# Training Epoch 3200/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.629
# Training Epoch 3201/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.912
# Training Epoch 3202/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.628
# Training Epoch 3203/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.912
# Training Epoch 3204/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.628
# Training Epoch 3205/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.913
# Training Epoch 3206/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.628
# Training Epoch 3207/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.913
# Training Epoch 3208/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.628
# Training Epoch 3209/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.913
# Training Epoch 3210/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.628
# Training Epoch 3211/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.914
# Training Epoch 3212/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.627
# Training Epoch 3213/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.914
# Training Epoch 3214/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.627
# Training Epoch 3215/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.914
# Training Epoch 3216/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.627
# Training Epoch 3217/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.915
# Training Epoch 3218/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.627
# Training Epoch 3219/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.915
# Training Epoch 3220/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.627
# Training Epoch 3221/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.916
# Training Epoch 3222/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.626
# Training Epoch 3223/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.916
# Training Epoch 3224/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.626
# Training Epoch 3225/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.916
# Training Epoch 3226/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.626
# Training Epoch 3227/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.917
# Training Epoch 3228/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.626
# Training Epoch 3229/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.917
# Training Epoch 3230/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.626
# Training Epoch 3231/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.917
# Training Epoch 3232/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.625
# Training Epoch 3233/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.918
# Training Epoch 3234/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.625
# Training Epoch 3235/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.918
# Training Epoch 3236/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.625
# Training Epoch 3237/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.918
# Training Epoch 3238/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.625
# Training Epoch 3239/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.919
# Training Epoch 3240/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.624
# Training Epoch 3241/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.919
# Training Epoch 3242/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.624
# Training Epoch 3243/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.919
# Training Epoch 3244/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.624
# Training Epoch 3245/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.920
# Training Epoch 3246/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.624
# Training Epoch 3247/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.920
# Training Epoch 3248/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.624
# Training Epoch 3249/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.920
# Training Epoch 3250/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.623
# Training Epoch 3251/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.921
# Training Epoch 3252/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.623
# Training Epoch 3253/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.921
# Training Epoch 3254/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.623
# Training Epoch 3255/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.921
# Training Epoch 3256/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.623
# Training Epoch 3257/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.922
# Training Epoch 3258/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.623
# Training Epoch 3259/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.922
# Training Epoch 3260/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.622
# Training Epoch 3261/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.922
# Training Epoch 3262/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.622
# Training Epoch 3263/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.923
# Training Epoch 3264/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.622
# Training Epoch 3265/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.923
# Training Epoch 3266/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.622
# Training Epoch 3267/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.924
# Training Epoch 3268/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.621
# Training Epoch 3269/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.924
# Training Epoch 3270/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.621
# Training Epoch 3271/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.924
# Training Epoch 3272/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.621
# Training Epoch 3273/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.925
# Training Epoch 3274/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.621
# Training Epoch 3275/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.925
# Training Epoch 3276/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.621
# Training Epoch 3277/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.925
# Training Epoch 3278/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.620
# Training Epoch 3279/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.926
# Training Epoch 3280/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.620
# Training Epoch 3281/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.926
# Training Epoch 3282/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.620
# Training Epoch 3283/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.926
# Training Epoch 3284/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.620
# Training Epoch 3285/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.927
# Training Epoch 3286/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.619
# Training Epoch 3287/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.927
# Training Epoch 3288/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.619
# Training Epoch 3289/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.927
# Training Epoch 3290/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.619
# Training Epoch 3291/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.928
# Training Epoch 3292/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.619
# Training Epoch 3293/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.928
# Training Epoch 3294/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.618
# Training Epoch 3295/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.928
# Training Epoch 3296/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.618
# Training Epoch 3297/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.929
# Training Epoch 3298/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.618
# Training Epoch 3299/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.929
# Training Epoch 3300/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.618
# Training Epoch 3301/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.929
# Training Epoch 3302/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.618
# Training Epoch 3303/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.930
# Training Epoch 3304/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.617
# Training Epoch 3305/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.930
# Training Epoch 3306/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.617
# Training Epoch 3307/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.930
# Training Epoch 3308/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.617
# Training Epoch 3309/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.931
# Training Epoch 3310/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.617
# Training Epoch 3311/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.931
# Training Epoch 3312/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.617
# Training Epoch 3313/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.931
# Training Epoch 3314/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.616
# Training Epoch 3315/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.931
# Training Epoch 3316/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.616
# Training Epoch 3317/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.932
# Training Epoch 3318/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.616
# Training Epoch 3319/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.932
# Training Epoch 3320/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.616
# Training Epoch 3321/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.932
# Training Epoch 3322/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.615
# Training Epoch 3323/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.933
# Training Epoch 3324/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.615
# Training Epoch 3325/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.933
# Training Epoch 3326/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.615
# Training Epoch 3327/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.933
# Training Epoch 3328/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.615
# Training Epoch 3329/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.934
# Training Epoch 3330/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.615
# Training Epoch 3331/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.934
# Training Epoch 3332/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.614
# Training Epoch 3333/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  81.2%,  Validation Loss: 0.934
# Training Epoch 3334/3334 --- Training Accuracy: 100.0%, Validation Accuracy:  75.0%,  Validation Loss: 2.614
#
# Execution Time: 1.2302824258142047 hours

# %% [markdown]
# Once your model is trained you can run this on your landscape

# %%
import tensorflow as tf
import numpy as np
import os
import cv2
import time
import csv


start = time.time()
csvFile = open('siteClass.csv', 'w', newline='')
csvWriter = csv.writer(csvFile)

try:
    
    # Path of  training images
    train_path = 'data/train'
    if not os.path.exists(train_path):
        print("No such directory")
        raise Exception
    # Path of testing images
    dir_path = 'data/test'
    if not os.path.exists(dir_path):
        print("No such directory")
        raise Exception
    
    # Walk though all testing images one by one
    for root, dirs, files in os.walk(dir_path):
        for name in files:

            print("")
            image_path = name
            filename = dir_path +'/' +image_path
            print(filename)
            image_size=256
            num_channels=3
            images = []
        
            if os.path.exists(filename):
                
                # Reading the image using OpenCV
                image = cv2.imread(filename)
                # Resizing the image to our desired size and preprocessing will be done exactly as done during training
                image = cv2.resize(image, (image_size, image_size),0,0, cv2.INTER_LINEAR)
                images.append(image)
                images = np.array(images, dtype=np.uint8)
                images = images.astype('float32')
                images = np.multiply(images, 1.0/255.0) 
            
                # The input to the network is of shape [None image_size image_size num_channels]. Hence we reshape.
                x_batch = images.reshape(1, image_size,image_size,num_channels)

                # Let us restore the saved model 
                sess = tf.Session()
                # Step-1: Recreate the network graph. At this step only graph is created.
                saver = tf.train.import_meta_graph('models/siteClassifier.meta')
                # Step-2: Now let's load the weights saved using the restore method.
                saver.restore(sess, tf.train.latest_checkpoint('models/'))

                # Accessing the default graph which we have restored
                graph = tf.get_default_graph()

                # Now, let's get hold of the op that we can be processed to get the output.
                # In the original network y_pred is the tensor that is the prediction of the network
                y_pred = graph.get_tensor_by_name("y_pred:0")

                ## Let's feed the images to the input placeholders
                x= graph.get_tensor_by_name("x:0") 
                y_true = graph.get_tensor_by_name("y_true:0") 
                y_test_images = np.zeros((1, len(os.listdir(train_path)))) 


                # Creating the feed_dict that is required to be fed to calculate y_pred 
                feed_dict_testing = {x: x_batch, y_true: y_test_images}
                result=sess.run(y_pred, feed_dict=feed_dict_testing)
                # Result is of this format [[probabiliy_of_classA probability_of_classB ....]]
                print(result)

                # Convert np.array to list
                a = result[0].tolist()
                r=0

                # Finding the maximum of all outputs
                max1 = max(a)
                index1 = a.index(max1)
                predicted_class = None

                # Walk through directory to find the label of the predicted output
                count = 0
                for root, dirs, files in os.walk(train_path):
                    for name in dirs:
                        if count==index1:
                            predicted_class = name
                        count+=1

                # If the maximum confidence output is largest of all by a big margin then
                # print the class or else print a warning
                for i in a:
                    if i!=max1:
                        if max1-i<i:
                            r=1                           
                if r ==0:
                    print(predicted_class)
                else:
                    print("Could not classify with definite confidence")
                    print("Maybe:",predicted_class)
                curRow = []
                curRow.append(image_path)
                curRow.append(predicted_class)
                csvWriter.writerow(curRow)
            # If file does not exist
            else:
                print("File does not exist")
                
except Exception as e:
    print("Exception:",e)

# Calculate execution time
end = time.time()
dur = end-start
print("")
if dur<60:
    print("Execution Time:",dur,"seconds")
elif dur>60 and dur<3600:
    dur=dur/60
    print("Execution Time:",dur,"minutes")
else:
    dur=dur/(60*60)
    print("Execution Time:",dur,"hours")
# Out:
# data/test/site_128_128.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[0.         0.99846363 0.00153641]]
# site2ds
#
# data/test/site_128_640.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[3.9781980e-06 2.6062741e-03 9.9738973e-01]]
# site2solar
#
# data/test/site_128_512.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[2.1248884e-03 3.1163271e-08 9.9787509e-01]]
# site2solar
#
# data/test/site_256_384.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[3.3434642e-09 8.5378069e-08 9.9999988e-01]]
# site2solar
#
# data/test/site_128_896.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[9.9999988e-01 9.9202451e-09 1.0309409e-07]]
# site2pwrplnt
#
# data/test/site_128_256.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[8.3771943e-33 9.9999964e-01 4.1665712e-07]]
# site2ds
#
# data/test/site_0_512.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[7.7638234e-09 9.9950325e-01 4.9670873e-04]]
# site2ds
#
# data/test/site_128_768.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[0.15530644 0.7992208  0.04547276]]
# site2ds
#
# data/test/site_256_256.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[1.1407728e-23 4.8367579e-22 1.0000000e+00]]
# site2solar
#
# data/test/site_128_0.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[7.5128239e-33 6.8923545e-14 1.0000000e+00]]
# site2solar
#
# data/test/site_256_128.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[1.9248195e-35 2.4060249e-14 1.0000000e+00]]
# site2solar
#
# data/test/site_0_896.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[9.5680346e-11 7.9375229e-07 9.9999917e-01]]
# site2solar
#
# data/test/site_256_0.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[0.000000e+00 8.121207e-22 1.000000e+00]]
# site2solar
#
# data/test/site_128_384.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[5.6819864e-15 2.1176046e-01 7.8823960e-01]]
# site2solar
#
# data/test/site_0_256.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[2.2341870e-25 9.9999988e-01 7.3084585e-08]]
# site2ds
#
# data/test/site_0_768.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[1.6962682e-05 2.9345934e-04 9.9968958e-01]]
# site2solar
#
# data/test/site_256_640.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[2.2965004e-07 4.0366249e-06 9.9999571e-01]]
# site2solar
#
# data/test/site_0_0.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[0.0000000e+00 1.0748435e-13 1.0000000e+00]]
# site2solar
#
# data/test/site_0_384.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[9.286035e-12 7.999391e-03 9.920006e-01]]
# site2solar
#
# data/test/site_0_128.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[7.7732320e-27 1.3964724e-06 9.9999857e-01]]
# site2solar
#
# data/test/site_256_512.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[2.3865342e-08 9.9980539e-01 1.9464399e-04]]
# site2ds
#
# data/test/site_0_640.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[0.00450798 0.00435249 0.9911396 ]]
# site2solar
#
# data/test/site_256_768.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[0.10034548 0.8297734  0.0698811 ]]
# site2ds
#
# data/test/site_384_896.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[9.9997878e-01 2.7742185e-06 1.8481769e-05]]
# site2pwrplnt
#
# data/test/site_896_768.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[2.0524123e-01 7.9461837e-01 1.4035942e-04]]
# site2ds
#
# data/test/site_384_384.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[1.0580520e-09 7.0443344e-01 2.9556656e-01]]
# site2ds
#
# data/test/site_512_896.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[8.2318943e-12 7.8589582e-01 2.1410416e-01]]
# site2ds
#
# data/test/site_384_128.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[9.385556e-34 9.293811e-12 1.000000e+00]]
# site2solar
#
# data/test/site_896_128.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[0.22337948 0.28771254 0.488908  ]]
# Could not classify with definite confidence
# Maybe: site2solar
#
# data/test/site_512_640.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[7.752144e-02 3.262495e-07 9.224782e-01]]
# site2solar
#
# data/test/site_640_640.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[9.685985e-01 3.140058e-02 8.668071e-07]]
# site2pwrplnt
#
# data/test/site_896_896.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[2.0975776e-03 9.9790120e-01 1.1771398e-06]]
# site2ds
#
# data/test/site_768_768.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[3.4183845e-02 6.2182895e-04 9.6519428e-01]]
# site2solar
#
# data/test/site_768_512.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[3.6913945e-05 6.6136685e-04 9.9930167e-01]]
# site2solar
#
# data/test/site_896_0.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[9.5426387e-01 4.5487840e-02 2.4834712e-04]]
# site2pwrplnt
#
# data/test/site_384_512.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[1.7984747e-05 6.2515661e-02 9.3746632e-01]]
# site2solar
#
# data/test/site_768_640.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[0.06825147 0.929715   0.00203354]]
# site2ds
#
# data/test/site_256_896.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[1.0000000e+00 2.4988635e-08 9.6698383e-09]]
# site2pwrplnt
#
# data/test/site_512_0.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[4.0952462e-25 4.0353272e-09 1.0000000e+00]]
# site2solar
#
# data/test/site_640_896.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[1.127132e-19 1.477848e-07 9.999999e-01]]
# site2solar
#
# data/test/site_384_768.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[3.7393484e-09 4.9186397e-01 5.0813603e-01]]
# Could not classify with definite confidence
# Maybe: site2solar
#
# data/test/site_640_512.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[9.9947649e-01 3.9107144e-05 4.8440538e-04]]
# site2pwrplnt
#
# data/test/site_384_0.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[0.0000000e+00 2.8148488e-22 1.0000000e+00]]
# site2solar
#
# data/test/site_512_256.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[1.5533355e-15 9.6302110e-01 3.6978915e-02]]
# site2ds
#
# data/test/site_640_384.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[0.00310869 0.00272774 0.9941636 ]]
# site2solar
#
# data/test/site_640_768.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[6.4992619e-06 7.9149177e-04 9.9920207e-01]]
# site2solar
#
# data/test/site_768_128.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[4.7112163e-04 4.2796927e-03 9.9524915e-01]]
# site2solar
#
# data/test/site_640_0.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[7.8429949e-13 9.9976343e-01 2.3653396e-04]]
# site2ds
#
# data/test/site_896_384.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[9.9021018e-01 6.0761353e-04 9.1822157e-03]]
# site2pwrplnt
#
# data/test/site_768_256.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[7.3622112e-07 7.5641804e-10 9.9999928e-01]]
# site2solar
#
# data/test/site_512_128.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[3.1569934e-16 1.7094089e-02 9.8290598e-01]]
# site2solar
#
# data/test/site_640_128.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[1.4374563e-05 5.7342131e-05 9.9992824e-01]]
# site2solar
#
# data/test/site_384_640.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[1.0458998e-10 4.4618724e-03 9.9553812e-01]]
# site2solar
#
# data/test/site_512_384.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[7.3821530e-12 9.7651678e-01 2.3483194e-02]]
# site2ds
#
# data/test/site_384_256.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[2.5384966e-20 8.2097657e-04 9.9917895e-01]]
# site2solar
#
# data/test/site_768_896.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[1.5020762e-08 4.7567033e-07 9.9999952e-01]]
# site2solar
#
# data/test/site_512_512.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[8.6576736e-01 1.3358054e-01 6.5203785e-04]]
# site2pwrplnt
#
# data/test/site_896_640.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[0.9931142  0.00290011 0.00398566]]
# site2pwrplnt
#
# data/test/site_896_512.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[9.4390070e-01 2.2175328e-08 5.6099229e-02]]
# site2pwrplnt
#
# data/test/site_512_768.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[3.6692626e-08 5.0603558e-07 9.9999940e-01]]
# site2solar
#
# data/test/site_768_0.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[9.8964864e-01 5.3264381e-04 9.8187868e-03]]
# site2pwrplnt
#
# data/test/site_640_256.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[1.6932845e-10 4.1692960e-03 9.9583071e-01]]
# site2solar
#
# data/test/site_896_256.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[0.17705134 0.7949797  0.02796895]]
# site2ds
#
# data/test/site_768_384.png
# INFO:tensorflow:Restoring parameters from models/siteClassifier
# [[2.8217018e-02 1.0353797e-04 9.7167945e-01]]
# site2solar
#
# Execution Time: 3.2942315101623536 minutes

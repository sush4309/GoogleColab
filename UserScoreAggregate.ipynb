# %% [markdown]
# Average Emotional scores to single value per user

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/twitterScrape
# Out:
# /content/drive/.shortcut-targets-by-id/1xRP1Q8_Og1uFKDrfOwKZW7pSM0lnuyne/twitterScrape

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !apt install -qq enchant
# !pip install pyenchant
# Out:
# The following additional packages will be installed:
#   aspell aspell-en dictionaries-common emacsen-common hunspell-en-us
#   libaspell15 libenchant1c2a libhunspell-1.6-0 libtext-iconv-perl
# Suggested packages:
#   aspell-doc spellutils wordlist hunspell openoffice.org-hunspell
#   | openoffice.org-core libenchant-voikko
# The following NEW packages will be installed:
#   aspell aspell-en dictionaries-common emacsen-common enchant hunspell-en-us
#   libaspell15 libenchant1c2a libhunspell-1.6-0 libtext-iconv-perl
# 0 upgraded, 10 newly installed, 0 to remove and 13 not upgraded.
# Need to get 1,310 kB of archives.
# After this operation, 5,353 kB of additional disk space will be used.
# Preconfiguring packages ...
# Selecting previously unselected package libtext-iconv-perl.
# (Reading database ... 146374 files and directories currently installed.)
# Preparing to unpack .../0-libtext-iconv-perl_1.7-5build6_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-5build6) ...
# ...

# %%
import csv
import pandas as pd
import math
import os
import enchant

def main():
    #make a csv file for output
    csvFile = open('user_singleSCore.csv','w')
    csvWriter = csv.writer(csvFile)

    #import the scored csv as a pandas data table
    data.pd.read_csv("twitter_userScore",header = 0)
    data.head()
    data.columns = map(str.lower,data.columns)
    data['users'] = data['users'].str.strip('[')
    data['users'] = data['users'].str.strip(']')
    data['users'] = data['users'].str.replace(" ", "")
    data['users'] = data['users'].str.split(',')
    users = data['user']
    users = list(set(users))
    print(users)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-493a8f63a531> in <module>()
#      23
#      24 if __name__ == "__main__":
# ---> 25     main()
#
# <ipython-input-8-493a8f63a531> in main()
#       7 def main():
#       8     #make a csv file for output
# ----> 9     csvFile = open('user_singleSCore.csv','w')
#      10     csvWriter = csv.writer(csvFile)
#      11
#
# OSError: [Errno 30] Read-only file system: 'user_singleSCore.csv'

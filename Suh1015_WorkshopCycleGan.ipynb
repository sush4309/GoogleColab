# %% [markdown]
# Mount your google Drive below

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Next we will copy over from github the model folders **Only Run this the first time you use the script**

# %%
# %cd /content/drive/My\ Drive
# !mkdir colabCycleGan
# %cd colabCycleGan
# !git clone https://github.com/mcaseyrehm/ColabCycleGan
# Out:
# /content/drive/My Drive
# mkdir: cannot create directory ‘colabCycleGan’: File exists
# /content/drive/My Drive/colabCycleGan
# fatal: destination path 'ColabCycleGan' already exists and is not an empty directory.

# %% [markdown]
# change to cyclegan directory

# %%
# %cd /content/drive/My\ Drive/colabCycleGan/ColabCycleGan/CycleGAN-tensorflow-master
# Out:
# /content/drive/My Drive/colabCycleGan/ColabCycleGan/CycleGAN-tensorflow-master

# %% [markdown]
# If you don't already have a dataset folder run this

# %%
# !mkdir datasets
# Out:
# mkdir: cannot create directory ‘datasets’: File exists

# %% [markdown]
# Set Tensorflow to 1.15

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# We will need to setup a specific folder for our images in the datset folder.  Inside of this folder make: trainA, trainB, testA, testB
# Copy some of the images (about 10) from your trainA set into testA and do the same for testB.
#
# If starting a new train run below

# %%
# !python main.py --dataset_dir=wall2dis
# Out:
# Streaming output truncated to the last 5000 lines.
# W1205 11:53:25.478147 139910300620672 util.py:61] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1205 11:53:25.486737 139910300620672 util.py:61] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Epoch: [290] [ 100/ 500] time: 30646.8162
# Epoch: [290] [ 101/ 500] time: 30647.0192
# Epoch: [290] [ 102/ 500] time: 30647.2265
# Epoch: [290] [ 103/ 500] time: 30647.4295
# Epoch: [290] [ 104/ 500] time: 30647.6339
# Epoch: [290] [ 105/ 500] time: 30647.8395
# Epoch: [290] [ 106/ 500] time: 30648.0442
# Epoch: [290] [ 107/ 500] time: 30648.2486
# Epoch: [290] [ 108/ 500] time: 30648.4537
# Epoch: [290] [ 109/ 500] time: 30648.6579
# Epoch: [290] [ 110/ 500] time: 30648.8632
# Epoch: [290] [ 111/ 500] time: 30649.0706
# Epoch: [290] [ 112/ 500] time: 30649.2814
# ...

# %% [markdown]
# If restarting a train from an existing checkpoint

# %%
# !python main.py --dataset_dir=wall2dis --continue_train=true
# Out:
# Streaming output truncated to the last 5000 lines.
# W1206 03:26:04.482965 139645162506112 util.py:61] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# W1206 03:26:04.988473 139645162506112 util.py:61] Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Epoch: [290] [ 100/ 500] time: 31817.9927
# Epoch: [290] [ 101/ 500] time: 31818.1934
# Epoch: [290] [ 102/ 500] time: 31818.3987
# Epoch: [290] [ 103/ 500] time: 31818.6039
# Epoch: [290] [ 104/ 500] time: 31818.8072
# Epoch: [290] [ 105/ 500] time: 31819.0154
# Epoch: [290] [ 106/ 500] time: 31819.2345
# Epoch: [290] [ 107/ 500] time: 31819.4526
# Epoch: [290] [ 108/ 500] time: 31819.6657
# Epoch: [290] [ 109/ 500] time: 31819.8804
# Epoch: [290] [ 110/ 500] time: 31820.0822
# Epoch: [290] [ 111/ 500] time: 31820.2843
# Epoch: [290] [ 112/ 500] time: 31820.4875
# ...

# %% [markdown]
# Once your network is trained run this:

# %%
# !python main.py --dataset_dir=wall2dis --phase=test --which_direction=AtoB
# Out:
# WARNING:tensorflow:From main.py:4: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From main.py:53: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From main.py:45: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W1208 00:43:53.538492 140034746947456 module_wrapper.py:139] From main.py:45: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# ...

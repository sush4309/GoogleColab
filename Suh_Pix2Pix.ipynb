# %% [markdown]
# Mount your google Drive below

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Next we will copy over from github the model folders **Only Run this the first time you use the script**

# %%
# %cd /content/drive/My\ Drive
# !mkdir colabpix2pix
# %cd colabpix2pix
# !git clone https://github.com/mcaseyrehm/pix2pixColab
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/colabpix2pix
# Cloning into 'pix2pixColab'...
# remote: Enumerating objects: 79, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 79 (delta 3), reused 79 (delta 3), pack-reused 0
# Unpacking objects: 100% (79/79), done.

# %% [markdown]
# change to pix2pix directory

# %%
# %cd /content/drive/My\ Drive/colabpix2pix/pix2pixColab
# Out:
# /content/drive/My Drive/colabpix2pix/pix2pixColab

# %% [markdown]
# Set Tensorflow to 1.15

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# If you need to create a joined dataset run this

# %%
# !python tools/process.py --input_dir trainA --b_dir trainB --operation combine --output_dir Interior
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/colabpix2pix/pix2pixColab/tools/tfimage.py:22: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/colabpix2pix/pix2pixColab/tools/tfimage.py:23: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_ops.py:4015: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_ops.py:4016: setdiff1d (from tensorflow.python.ops.array_ops) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# This op will be removed after the deprecation date. Please switch to tf.sets.difference().
# ...

# %% [markdown]
# If starting a new train run below

# %%
# !python pix2pix.py --mode train --output_dir InteriorTrain --input_dir Interior --display_freq 200
# Out:
# WARNING:tensorflow:From pix2pix.py:540: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# aspect_ratio = 1.0
# batch_size = 1
# beta1 = 0.5
# checkpoint = None
# display_freq = 200
# flip = True
# gan_weight = 1.0
# input_dir = Interior
# l1_weight = 100.0
# lab_colorization = False
# lr = 0.0002
# max_epochs = None
# max_steps = None
# mode = train
# ndf = 64
# ngf = 64
# output_dir = InteriorTrain
# output_filetype = png
# progress_freq = 50
# save_freq = 200
# scale_size = 256
# seed = 111425388
# separable_conv = False
# summary_freq = 100
# trace_freq = 0
# which_direction = AtoB
# WARNING:tensorflow:From pix2pix.py:258: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %% [markdown]
# If restarting a train from an existing checkpoint

# %%
# !python pix2pix.py --mode train --output_dir site2ADUTrain --input_dir site2ADUdata --display_freq 200 --checkpoint site2ADUTrain
# Out:
# WARNING:tensorflow:From pix2pix.py:540: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# aspect_ratio = 1.0
# batch_size = 1
# beta1 = 0.5
# checkpoint = site2ADUTrain
# display_freq = 200
# flip = True
# gan_weight = 1.0
# input_dir = site2ADUdata
# l1_weight = 100.0
# lab_colorization = False
# lr = 0.0002
# max_epochs = None
# max_steps = None
# mode = train
# ndf = 64
# ngf = 64
# output_dir = site2ADUTrain
# output_filetype = png
# progress_freq = 50
# save_freq = 200
# scale_size = 256
# seed = 1331493604
# separable_conv = False
# summary_freq = 100
# trace_freq = 0
# which_direction = AtoB
# WARNING:tensorflow:From pix2pix.py:258: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %% [markdown]
# Once your network is trained, you can run this to test

# %%
# !python pix2pix.py --mode test --output_dir result --input_dir input --checkpoint checkpoint
# Out:
# WARNING:tensorflow:From pix2pix.py:540: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# Traceback (most recent call last):
#   File "pix2pix.py", line 803, in <module>
#     main()
#   File "pix2pix.py", line 553, in main
#     with open(os.path.join(a.checkpoint, "options.json")) as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'checkpoint/options.json'
